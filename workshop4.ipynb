# %% [markdown]
# <a href="https://colab.research.google.com/github/khatriprashanna10-pixel/khatriprashanna10-pixel/blob/main/workshop4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 4MM013 Python Workshop Week-4

# %% [markdown]
# Python’s pyplot library will allow us to implement other graph types.
# Scatter
# Scatter graphs will plot one point per observation, we can use these to graph independent
# variables to see if there is a correlation. Python will require two sets of variables for a scatter
# graph, one for the x-axis and another for the corresponding y axis. These sets will need to be of
# the same length and work best as lists, array, or array-like data types. We can call ‘pyplot’ to plot
# a scatter with the pyplot.scatter(x,y) call for example.

# %% [markdown]
# Example 1

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8,9]
y=[3,4,5,6,7,8,9,10,11]
#plt.plot(x,y)
plt.scatter(x,y,color='red',marker='^')
plt.show()

# %% [markdown]
# We can also plot more than one series of x, y values on to the same graph, for example
# Output

# %% [markdown]
# Example 2

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8,9]
y=[3,4,5,6,7,1,9,2,5]
#plt.plot(x,y)
plt.scatter(x,y,color='red',marker='^')
x1=[1,5,6,8,12]
y1=[2,6,7,11,13]
plt.scatter(x1,y1,color='blue',marker='s')
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.title("Scatter plot")
plt.show()

# %% [markdown]
# Task-1:
# Create a scatter graph of 10 random x and y values between 0 and 50. Label the axis to show
# x – Time taken in seconds
# y – Distance reached
# Title “Buzzer Game Results”
# One you have a working program, add the following code to your program;
# colors=["red","green","blue","yellow","pink","orange","purple","brown"
# ,"cyan","magenta"]
# And add to your scatter() call the ‘c=colors’ argument like so;
# plt.scatter(x, y, c=colors)

# %%
import matplotlib.pyplot as plt
import random
x = []
y = []
for i in range(10):
    x.append(random.randint(0, 50))
    y.append(random.randint(0, 50))
colors = ["red", "green", "blue", "yellow", "pink",
          "orange", "purple", "brown", "cyan", "magenta"]
plt.scatter(x, y, c=colors)
plt.xlabel("Time taken in seconds")
plt.ylabel("Distance reached")
plt.title("Buzzer Game Results")
plt.show()

# %% [markdown]
# What happens?
# Ans:Each point gets a different color from the list.

# %% [markdown]
# Pie Chart
# Example 3:

# %%
import matplotlib.pyplot as plt
y=[100,205,307,409,200]
groups=['Pulsar','Duke','Enfield','Honda','Hero']
plt.pie(y,labels=groups)
plt.show()

# %% [markdown]
# Task 2:
# Following data shows the change in population of different animals from 2017 to 2022.
# a. Create a pie chart for the population of each year
# b. Can we show all the pie chart on the single pane? Write the code.

# %%
import matplotlib.pyplot as plt
animals = ["Bears", "Dolphins", "Whales"]
pop2017 = [8, 150, 80]
pop2018 = [54, 77, 54]
pop2019 = [93, 32, 100]
pop2020 = [116, 11, 76]
pop2021 = [137, 6, 93]
pop2022 = [184, 1, 72]
years = [2017, 2018, 2019, 2020, 2021, 2022]
data = [pop2017, pop2018, pop2019, pop2020, pop2021, pop2022]
for i in range(len(data)):
    plt.figure()
    plt.pie(data[i], labels=animals, autopct="%1.1f%%")
    plt.title(f"Animal Population {years[i]}")
    plt.show()

# %%
import matplotlib.pyplot as plt
animals = ["Bears", "Dolphins", "Whales"]
data = [
    [8, 150, 80],      # 2017
    [54, 77, 54],      # 2018
    [93, 32, 100],     # 2019
    [116, 11, 76],     # 2020
    [137, 6, 93],      # 2021
    [184, 1, 72]       # 2022
]
years = ["2017", "2018", "2019", "2020", "2021", "2022"]
plt.figure(figsize=(10, 6))
for i in range(6):
    plt.subplot(2, 3, i + 1)
    plt.pie(data[i], labels=animals, autopct="%1.1f%%")
    plt.title(years[i])
plt.tight_layout()
plt.show()

# %% [markdown]
# Task 3:
# Construct a pie chart to visually display the favorite fruits of the students in a class based on the
# given data: Mango - 45; Orange - 30; Plum - 15; Pineapple - 30; Melon – 30

# %%
import matplotlib.pyplot as plt
fruits = ["Mango", "Orange", "Plum", "Pineapple", "Melon"]
values = [45, 30, 15, 30, 30]
plt.pie(values, labels=fruits, autopct="%1.1f%%")
plt.title("Favourite Fruits of Students")
plt.show()

# %% [markdown]
# Example 4

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
data = [23, 45, 56, 78, 213]
plt.bar(x, data, width=0.5, color="maroon")
plt.title("A Bar Plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# Task 4
#
# Here is some data to use for the tasks.
#
# Car color Number seen
#
# Red 123
# Silver 230
# Blue 78
# White 193
# Green 12
#
# a) Create a bar chart for the car data above.

# %%
import matplotlib.pyplot as plt
x = ["Red", "Silver", "Blue", "White", "Green"]
y = [123, 230, 78, 193, 12]
plt.bar(x, y)
plt.title("Number of Cars by Colour")
plt.xlabel("Car Colour")
plt.ylabel("Number Seen")
plt.show()

# %% [markdown]
# b) Implement the code “ plt.bar(x, y, width = 0.3)” to plot the bar chart, what is the effect?

# %%
import matplotlib.pyplot as plt
x = ["Red", "Silver", "Blue", "White", "Green"]
y = [123, 230, 78, 193, 12]
plt.bar(x, y, width=0.3)
plt.title("Number of Cars by Colour")
plt.xlabel("Car Colour")
plt.ylabel("Number Seen")
plt.show()

# %% [markdown]
# c) Implement the code “ plt.barh(x, y)” to plot the bar chart, what is the effect?

# %%
import matplotlib.pyplot as plt
x = ["Red", "Silver", "Blue", "White", "Green"]
y = [123, 230, 78, 193, 12]
plt.barh(x, y)
plt.title("Number of Cars by Colour")
plt.xlabel("Number Seen")
plt.ylabel("Car Colour")
plt.show()

# %% [markdown]
# d) Create a list of colors and using the “ plt.bar(x, y, color = {you list here} ) “set the bar
# chart colors to be the same as the car colors each bar represents.

# %%
import matplotlib.pyplot as plt
x = ["Red", "Silver", "Blue", "White", "Green"]
y = [123, 230, 78, 193, 12]
colors = ["red", "silver", "blue", "white", "green"]
plt.bar(x, y, color=colors)
plt.title("Number of Cars by Colour")
plt.xlabel("Car Colour")
plt.ylabel("Number Seen")
plt.show()

# %% [markdown]
# e) Create a pie chart of the car data above and add a title

# %%
import matplotlib.pyplot as plt
labels = ["Red", "Silver", "Blue", "White", "Green"]
sizes = [123, 230, 78, 193, 12]
plt.pie(sizes, labels=labels, autopct="%1.1f%%")
plt.title("Car Colours")
plt.show()

# %% [markdown]
# f) Test out the following pie chart additional arguments / settings (“...” is for the normal
# code you have already)

# %%
import matplotlib.pyplot as plt
labels = ["Red", "Silver", "Blue", "White", "Green"]
sizes = [123, 230, 78, 193, 12]
myexplode = [0.3, 0, 0, 0, 0]
plt.pie(sizes, labels=labels, explode=myexplode, autopct="%1.1f%%")
plt.title("Car Colours")
plt.show()

# %% [markdown]
# myexplode = [0.3, 0, 0, 0]
# plt.pie(... , explode = myexplode,shadow = True)

# %%
import matplotlib.pyplot as plt
labels = ["Red", "Silver", "Blue", "White", "Green"]
sizes = [123, 230, 78, 193, 12]
myexplode = [0.3, 0, 0, 0, 0]
plt.pie(sizes, labels=labels, explode=myexplode, shadow=True, autopct="%1.1f%%")
plt.title("Car Colours")
plt.show()

# %% [markdown]
# plt.legend(title = "Car Colours:")

# %%
import matplotlib.pyplot as plt
labels = ["Red", "Silver", "Blue", "White", "Green"]
sizes = [123, 230, 78, 193, 12]
plt.pie(sizes, labels=labels, autopct="%1.1f%%")
plt.legend(title="Car Colours:")
plt.title("Car Colours")
plt.show()

# %% [markdown]
# mycolours = ["Magenta", "Green", "Cyan", "Red"]
# plt.pie(... , colors = mycolours)

# %%
import matplotlib.pyplot as plt
labels = ["Red", "Silver", "Blue", "White", "Green"]
sizes = [123, 230, 78, 193, 12]
mycolours = ["Magenta", "Green", "Cyan", "Red", "Yellow"]
plt.pie(sizes, labels=labels, colors=mycolours, autopct="%1.1f%%")
plt.title("Car Colours")
plt.show()
